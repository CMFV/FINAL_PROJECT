# %%
import pandas as pd
import numpy as np
import re
import tqdm as tqdm

# %%
food_components=pd.read_csv('Copia de Simplified Nutrition Facts from the USDA Release 28 (2016) Version 1 - Sheet1.csv')
food_components
# Out:
#       Database Number                         Food Group  \
# 0                1001             Dairy and Egg Products
# 1                1002             Dairy and Egg Products
# 2                1003             Dairy and Egg Products
# 3                1004             Dairy and Egg Products
# 4                1005             Dairy and Egg Products
# 5                1006             Dairy and Egg Products
# 6                1007             Dairy and Egg Products
# 7                1008             Dairy and Egg Products
# 8                1009             Dairy and Egg Products
# 9                1010             Dairy and Egg Products
# 10               1011             Dairy and Egg Products
# 11               1012             Dairy and Egg Products
# 12               1013             Dairy and Egg Products
# 13               1014             Dairy and Egg Products
# 14               1015             Dairy and Egg Products
# ...

# %%
food_components.columns
# Out:
# Index(['Database Number', 'Food Group', 'Food Name', 'Protein (g)', 'Fat (g)',
#        'Carbohydrates (g)', 'Ash (g)', 'Calories', 'Starch (g)', 'Sucrose (g)',
#        'Glucose (g)', 'Fructose (g)', 'Lactose (g)', 'Maltose (g)',
#        'Alcohol (g)', 'Water (g)', 'Caffeine (mg)', 'Theobromine (mg)',
#        'Sugar (g)', 'Galactose (g)', 'Fiber (g)', 'Calcium (mg)', 'Iron (mg)',
#        'Magnesium (mg)', 'Phosphorus (mg)', 'Potasssium (mg)', 'Sodium (mg)',
#        'Zinc (mg)', 'Cupper (mg)', 'Fluoride (mcg)', 'Manganese (mg)',
#        'Selenium (mcg)', 'Vitamin A (IU)', 'Retinol (mcg)',
#        'Retinol Equivalents (mcg)', 'Beta Carotene (mcg)',
#        'Alpha Carotene (mcg)', 'Vitamin E (mg)', 'Vitamin D (mcg)',
#        'Vitamin D2 (Ergocalciferol)  (mcg)',
#        'Vitamin D3 (Cholecalciferol) (mcg)', 'Beta Cryptoxanthin (mcg)',
#        'Lycopene (mcg)', 'Lutein and Zeaxanthin (mcg)', 'Vitamin C (mg)',
# ...

# %%
food_components['Sugar (g)'].isna().sum()
# Out:
# 1541

# %%
food_components['Food Group'].value_counts()
# Out:
# Beef Products                        961
# Vegetables and Vegetable Products    836
# Baked Products                       487
# Lamb, Veal, and Game Products        464
# Legumes and Legume Products          374
# Beverages                            371
# Sweets                               360
# Fruits and Fruit Juices              353
# Poultry Products                     333
# Pork Products                        323
# Dairy and Egg Products               272
# Finfish and Shellfish Products       264
# Snacks                               175
# Cereal Grains and Pasta              172
# Sausages and Luncheon Meats          160
# Fats and Oils                        152
# Nut and Seed Products                137
# Spices and Herbs                      64
# Soups, Sauces, and Gravies            50
# Baby Foods                            26
# Breakfast Cereals                     13
# Name: Food Group, dtype: int64

# %%
#def search(keyword, df):
#    search = '|'.join(keyword)
#    searched = df[df['text'].str.contains(search, na=False)]
#    return searched

#search('Cheese', 'food_components')

# %%
food_components[food_components['Food Name'].str.contains("bread")]
# Out:
#       Database Number                         Food Group  \
# 363              4546                      Fats and Oils
# 616              5300                   Poultry Products
# 631              5326                   Poultry Products
# 632              5327                   Poultry Products
# 1793            11295  Vegetables and Vegetable Products
# 1794            11296  Vegetables and Vegetable Products
# 2301            11940  Vegetables and Vegetable Products
# 2308            11948  Vegetables and Vegetable Products
# 2356            12001              Nut and Seed Products
# 2357            12003              Nut and Seed Products
# 2358            12004              Nut and Seed Products
# 2359            12005              Nut and Seed Products
# 2443            12158              Nut and Seed Products
# 3243            15011     Finfish and Shellfish Products
# 3253            15021     Finfish and Shellfish Products
# ...

# %%
food_components2=pd.read_csv('Las Tablas de Wahls - Hoja 2.csv')
food_components2.head()
# Out:
#    alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code     alim_grp_nom_eng  \
# 0              1              101                  0  starters and dishes
# 1              1              101                  0  starters and dishes
# 2              1              101                  0  starters and dishes
# 3              1              101                  0  starters and dishes
# 4              1              101                  0  starters and dishes
#
#   alim_ssgrp_nom_eng alim_ssssgrp_nom_eng  alim_code  \
# 0       mixed salads                    -      25600
# 1       mixed salads                    -      25601
# 2       mixed salads                    -      25602
# 3       mixed salads                    -      25605
# 4       mixed salads                    -      25606
#
#                                         alim_nom_eng  \
# 0             Celeriac in remoulade sauce, prepacked
# 1  Prepared mixed tuna and vegetable salad, canne...
# ...

# %%
food_components2['alim_grp_nom_eng'].value_counts()
# Out:
# meat, egg and fish                      739
# fruits, vegetables, legumes and nuts    437
# cereal products                         402
# starters and dishes                     308
# beverages                               274
# milk and milk products                  245
# miscellaneous                           191
# fats and oils                            71
# sugar and confectionery                  67
# baby food                                36
# ice cream and sorbet                     26
# Name: alim_grp_nom_eng, dtype: int64

# %%
food_components2.columns
# Out:
# Index(['alim_grp_code', 'alim_ssgrp_code', 'alim_ssssgrp_code',
#        'alim_grp_nom_eng', 'alim_ssgrp_nom_eng', 'alim_ssssgrp_nom_eng',
#        'alim_code', 'alim_nom_eng', 'alim_nom_eng.1',
#        'Energy, Regulation EU No 1169/2011 (kcal/100g)',
#        'Energy, N x Jones' factor, with fibres (kJ/100g)',
#        'Energy, N x Jones' factor, with fibres (kcal/100g)', 'Water (g/100g)',
#        'Protein (g/100g)', 'Protein, crude, N x 6.25 (g/100g)',
#        'Carbohydrate (g/100g)', 'Fat (g/100g)', 'Sugars (g/100g)',
#        'Starch (g/100g)', 'Fibres (g/100g)', 'Polyols (g/100g)',
#        'Ash (g/100g)', 'Alcohol (g/100g)', 'Organic acids (g/100g)',
#        'FA saturated (g/100g)', 'FA mono (g/100g)', 'FA poly (g/100g)',
#        'FA 4:0 (g/100g)', 'FA 6:0 (g/100g)', 'FA 8:0 (g/100g)',
#        'FA 10:0 (g/100g)', 'FA 12:0 (g/100g)', 'FA 14:0 (g/100g)',
#        'FA 16:0 (g/100g)', 'FA 18:0 (g/100g)', 'FA 18:1 n-9 cis (g/100g)',
# ...

# %%
food_components2.dtypes
# Out:
# alim_grp_code                                          int64
# alim_ssgrp_code                                        int64
# alim_ssssgrp_code                                      int64
# alim_grp_nom_eng                                      object
# alim_ssgrp_nom_eng                                    object
# alim_ssssgrp_nom_eng                                  object
# alim_code                                              int64
# alim_nom_eng                                          object
# alim_nom_eng.1                                        object
# Energy, Regulation EU No 1169/2011 (kcal/100g)        object
# Energy, N x Jones' factor, with fibres (kJ/100g)      object
# Energy, N x Jones' factor, with fibres (kcal/100g)    object
# Water (g/100g)                                        object
# Protein (g/100g)                                      object
# Protein, crude, N x 6.25 (g/100g)                     object
# ...

# %%
food_components2.columns
# Out:
# Index(['alim_grp_code', 'alim_ssgrp_code', 'alim_ssssgrp_code',
#        'alim_grp_nom_eng', 'alim_ssgrp_nom_eng', 'alim_ssssgrp_nom_eng',
#        'alim_code', 'alim_nom_eng', 'alim_nom_eng.1',
#        'Energy, Regulation EU No 1169/2011 (kcal/100g)',
#        'Energy, N x Jones' factor, with fibres (kJ/100g)',
#        'Energy, N x Jones' factor, with fibres (kcal/100g)', 'Water (g/100g)',
#        'Protein (g/100g)', 'Protein, crude, N x 6.25 (g/100g)',
#        'Carbohydrate (g/100g)', 'Fat (g/100g)', 'Sugars (g/100g)',
#        'Starch (g/100g)', 'Fibres (g/100g)', 'Polyols (g/100g)',
#        'Ash (g/100g)', 'Alcohol (g/100g)', 'Organic acids (g/100g)',
#        'FA saturated (g/100g)', 'FA mono (g/100g)', 'FA poly (g/100g)',
#        'FA 4:0 (g/100g)', 'FA 6:0 (g/100g)', 'FA 8:0 (g/100g)',
#        'FA 10:0 (g/100g)', 'FA 12:0 (g/100g)', 'FA 14:0 (g/100g)',
#        'FA 16:0 (g/100g)', 'FA 18:0 (g/100g)', 'FA 18:1 n-9 cis (g/100g)',
# ...

# %%
food_components.columns
# Out:
# Index(['Database Number', 'Food Group', 'Food Name', 'Protein (g)', 'Fat (g)',
#        'Carbohydrates (g)', 'Ash (g)', 'Calories', 'Starch (g)', 'Sucrose (g)',
#        'Glucose (g)', 'Fructose (g)', 'Lactose (g)', 'Maltose (g)',
#        'Alcohol (g)', 'Water (g)', 'Caffeine (mg)', 'Theobromine (mg)',
#        'Sugar (g)', 'Galactose (g)', 'Fiber (g)', 'Calcium (mg)', 'Iron (mg)',
#        'Magnesium (mg)', 'Phosphorus (mg)', 'Potasssium (mg)', 'Sodium (mg)',
#        'Zinc (mg)', 'Cupper (mg)', 'Fluoride (mcg)', 'Manganese (mg)',
#        'Selenium (mcg)', 'Vitamin A (IU)', 'Retinol (mcg)',
#        'Retinol Equivalents (mcg)', 'Beta Carotene (mcg)',
#        'Alpha Carotene (mcg)', 'Vitamin E (mg)', 'Vitamin D (mcg)',
#        'Vitamin D2 (Ergocalciferol)  (mcg)',
#        'Vitamin D3 (Cholecalciferol) (mcg)', 'Beta Cryptoxanthin (mcg)',
#        'Lycopene (mcg)', 'Lutein and Zeaxanthin (mcg)', 'Vitamin C (mg)',
# ...

# %%
food1=food_components2[['alim_ssgrp_nom_eng', 'alim_nom_eng',
       'Energy, Regulation EU No 1169/2011 (kcal/100g)','Water (g/100g)',
       'Protein (g/100g)','Carbohydrate (g/100g)', 'Fat (g/100g)', 'Sugars (g/100g)',
       'Starch (g/100g)', 'Fibres (g/100g)', 'Polyols (g/100g)',
       'Ash (g/100g)', 'Alcohol (g/100g)', 'Organic acids (g/100g)',
       'FA saturated (g/100g)', 'FA mono (g/100g)', 'FA poly (g/100g)',
       'FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)',
       'Cholesterol (mg/100g)', 'Salt (g/100g)', 'Calcium (mg/100g)',
       'Chloride (mg/100g)', 'Copper (mg/100g)', 'Iron (mg/100g)',
       'Iodine (µg/100g)', 'Magnesium (mg/100g)', 'Manganese (mg/100g)',
       'Phosphorus (mg/100g)', 'Potassium (mg/100g)', 'Selenium (µg/100g)',
       'Sodium (mg/100g)', 'Zinc (mg/100g)', 'Retinol (µg/100g)',
       'Beta-carotene (µg/100g)', 'Vitamin D (µg/100g)', 'Vitamin E (mg/100g)',
       'Vitamin K1 (µg/100g)', 'Vitamin K2 (µg/100g)', 'Vitamin C (mg/100g)',
       'Vitamin B1 or Thiamin (mg/100g)', 'Vitamin B2 or Riboflavin (mg/100g)',
       'Vitamin B3 or Niacin (mg/100g)',
       'Vitamin B5 or Pantothenic acid (mg/100g)', 'Vitamin B6 (mg/100g)',
       'Vitamin B9 or Folate (µg/100g)', 'Vitamin B12 (µg/100g)']]

# %%
food1.columns
# Out:
# Index(['alim_ssgrp_nom_eng', 'alim_nom_eng',
#        'Energy, Regulation EU No 1169/2011 (kcal/100g)', 'Water (g/100g)',
#        'Protein (g/100g)', 'Carbohydrate (g/100g)', 'Fat (g/100g)',
#        'Sugars (g/100g)', 'Starch (g/100g)', 'Fibres (g/100g)',
#        'Polyols (g/100g)', 'Ash (g/100g)', 'Alcohol (g/100g)',
#        'Organic acids (g/100g)', 'FA saturated (g/100g)', 'FA mono (g/100g)',
#        'FA poly (g/100g)', 'FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)',
#        'Cholesterol (mg/100g)', 'Salt (g/100g)', 'Calcium (mg/100g)',
#        'Chloride (mg/100g)', 'Copper (mg/100g)', 'Iron (mg/100g)',
#        'Iodine (µg/100g)', 'Magnesium (mg/100g)', 'Manganese (mg/100g)',
#        'Phosphorus (mg/100g)', 'Potassium (mg/100g)', 'Selenium (µg/100g)',
#        'Sodium (mg/100g)', 'Zinc (mg/100g)', 'Retinol (µg/100g)',
#        'Beta-carotene (µg/100g)', 'Vitamin D (µg/100g)', 'Vitamin E (mg/100g)',
# ...

# %%
food2=food_components[['Food Group', 'Food Name', 'Protein (g)', 'Fat (g)',
       'Carbohydrates (g)', 'Ash (g)', 'Calories', 'Starch (g)', 'Sucrose (g)',
       'Glucose (g)', 'Fructose (g)', 'Lactose (g)', 'Maltose (g)',
       'Alcohol (g)', 'Water (g)', 'Caffeine (mg)', 'Theobromine (mg)',
       'Sugar (g)', 'Galactose (g)', 'Fiber (g)', 'Calcium (mg)', 'Iron (mg)',
       'Magnesium (mg)', 'Phosphorus (mg)', 'Potasssium (mg)', 'Sodium (mg)',
       'Zinc (mg)', 'Cupper (mg)', 'Fluoride (mcg)', 'Manganese (mg)',
       'Selenium (mcg)', 'Vitamin A (IU)', 'Retinol (mcg)', 'Beta Carotene (mcg)',
       'Alpha Carotene (mcg)', 'Vitamin E (mg)', 'Vitamin D (mcg)',
       'Vitamin D2 (Ergocalciferol)  (mcg)',
       'Vitamin D3 (Cholecalciferol) (mcg)', 'Beta Cryptoxanthin (mcg)',
       'Lycopene (mcg)', 'Lutein and Zeaxanthin (mcg)', 'Vitamin C (mg)',
       'Thiamin (B1) (mg)', 'Riboflavin (B2) (mg)', 'Niacin (B3) (mg)',
       'Vitamin B5 (mg)', 'Vitamin B6 (mg)', 'Folate (B9) (mg)', 'Vitamin B12',
       'Choline (mg)', 'Cholesterol (mg)', 'Saturated Fat (g)']]

# %%
food2.rename(columns={
    "Food Group": "Group",
    'Food Name': "Name",
    'Protein (g)': 'Protein',
    'Fat (g)':'Fat',
    'Carbohydrates (g)':'Carbohydrates',
    'Ash (g)':'Ash',
    'Calories':'Calories',
    'Starch (g)':'Starch',
    'Sucrose (g)':'Sucrose',
    'Glucose (g)':'Glucose',
    'Fructose (g)': 'Fructose',
    'Lactose (g)':'Lactose',
    'Maltose (g)':'Maletose',
    'Alcohol (g)': 'Alcohol',
    'Water (g)':'Water',
    'Caffeine (mg)':'Caffeine',
    'Theobromine (mg)':'Theobromine',
    'Sugar (g)': 'Sugar',
    'Galactose (g)': 'Galactose',
    'Fiber (g)': 'Fiber',
    'Calcium (mg)':'Calcium',
    'Iron (mg)': 'Iron',
    'Magnesium (mg)': 'Magnesium',
    'Phosphorus (mg)': 'Phosphorus',
    'Potasssium (mg)': 'Potassium',
    'Sodium (mg)':'Sodium',
    'Zinc (mg)': 'Zinc',
    'Cupper (mg)': 'Cupper',
    'Fluoride (mcg)': 'Fluoride', 
    'Manganese (mg)': 'Manganese',
    'Selenium (mcg)': 'Selenium',
    'Vitamin A (IU)': 'Vitamin A', 
    'Retinol (mcg)': 'Retinol',
    'Beta Carotene (mcg)': 'Beta_Carotene',
    'Alpha Carotene (mcg)': 'Alpha_Carotene',
    'Vitamin E (mg)': 'Vitamin_E',
    'Vitamin D (mcg)': 'Vitamin_D',
    'Vitamin D2 (Ergocalciferol)  (mcg)': 'Vitamin_D2',
    'Vitamin D3 (Cholecalciferol) (mcg)': 'Vitamin_D3',
    'Beta Cryptoxanthin (mcg)':'Beta_Cryptoxanthin',
    'Lycopene (mcg)': 'Lycopene',
    'Lutein and Zeaxanthin (mcg)':'Lutein&Zeaxathin',
    'Vitamin C (mg)':'Vitamin_C',
    'Thiamin (B1) (mg)':'Vitamin_B1',
    'Riboflavin (B2) (mg)': 'Vitamin_B2',
    'Niacin (B3) (mg)': 'Vitamin_B3',
    'Vitamin B5 (mg)': 'Vitamin_B5',
    'Vitamin B6 (mg)': 'Vitamin_B6',
    'Folate (B9) (mg)': 'Vitamin_B9',
    'Vitamin B12': 'Vitamin_B12',
    'Choline (mg)': 'Choline',
    'Cholesterol (mg)': 'Cholesterol', 
    'Saturated Fat (g)': 'Saturated_Fat'
    },inplace=True)
food2.head()
# Out:
# /Users/claraFDEZ/miniconda3/envs/FINAL_PROJECT_ENV/lib/python3.7/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                     Group                        Name  Protein    Fat  \
# 0  Dairy and Egg Products              Butter, salted     0.85  81.11
# 1  Dairy and Egg Products  Butter, whipped, with salt     0.49  78.30
# 2  Dairy and Egg Products       Butter oil, anhydrous     0.28  99.48
# 3  Dairy and Egg Products                Cheese, blue    21.40  28.74
# 4  Dairy and Egg Products               Cheese, brick    23.24  29.68
#
#    Carbohydrates   Ash  Calories  Starch  Sucrose  Glucose  ...  Vitamin_B1  \
# 0           0.06  2.11       717     NaN      NaN      NaN  ...       0.005
# ...

# %%
food2=food2.assign(**{'Polyols':0, 'Organic_Acids':0, 'Fat_Mono.':0, 'Fat_Poly.':0, 'DHA':0, 'Salt':0, 'Iodine':0, 'Vitamin_K1':0, 'Vitamin_K2':0})
#rest_cols_f2=pd.DataFrame['Polyols', 'Organic_Acids', 'Fat_Mono.', 'Fat_Poly.', 'DHA', 'Salt', 'Iodine', 'Vitamin_K1', 'Vitamin_K2']
#food2=pd.concat(rest_cols_f2, food2)

# %%
food2.shape
# Out:
# (6347, 62)

# %%
food1.rename(columns={
    "alim_ssgrp_nom_eng":"Group",
    'alim_nom_eng': "Name",
    'Protein (g/100g)': 'Protein',
    'Fat (g/100g)':'Fat',
    'Carbohydrate (g/100g)':'Carbohydrates',
    'Ash (g/100g)':'Ash',
    'Energy, Regulation EU No 1169/2011 (kcal/100g)':'Calories',
    'Starch (g/100g)':'Starch',
    'Alcohol (g/100g)': 'Alcohol',
    'Water (g/100g)':'Water',
    'Sugars (g/100g)': 'Sugar',
    'Fibres (g/100g)': 'Fiber',
    'Calcium (mg/100g)':'Calcium',
    'Iron (mg/100g)': 'Iron',
    'Magnesium (mg/100g)': 'Magnesium',
    'Phosphorus (mg/100g)': 'Phosphorus',
    'Potassium (mg/100g)': 'Potassium',
    'Sodium (mg/100g)':'Sodium',
    'Zinc (mg/100g)': 'Zinc',
    'Copper (mg/100g)': 'Cupper', 
    'Manganese (mg/100g)': 'Manganese',
    'Selenium (µg/100g)': 'Selenium',
    'Retinol (µg/100g)': 'Retinol',
    'Beta-carotene (µg/100g)': 'Beta_Carotene',
    'Vitamin E (mg/100g)': 'Vitamin_E',
    'Vitamin D (µg/100g)': 'Vitamin_D',
    'Vitamin C (mg/100g)':'Vitamin_C',
    'Vitamin B1 or Thiamin (mg/100g)':'Vitamin_B1',
    'Vitamin B2 or Riboflavin (mg/100g)': 'Vitamin_B2',
    'Vitamin B3 or Niacin (mg/100g)': 'Vitamin_B3',
    'Vitamin B5 or Pantothenic acid (mg/100g)': 'Vitamin_B5',
    'Vitamin B6 (mg/100g)': 'Vitamin_B6',
    'Vitamin B9 or Folate (µg/100g)': 'Vitamin_B9',
    'Vitamin B12 (µg/100g)': 'Vitamin_B12',
    'Chloride (mg/100g)': 'Choline',
    'Cholesterol (mg/100g)': 'Cholesterol', 
    'FA saturated (g/100g)': 'Saturated_Fat',
    'Polyols (g/100g)':'Polyols',
    'Organic acids (g/100g)':'Organic_Acids', 
    'FA mono (g/100g)':'Fat_Mono.', 
    'FA poly (g/100g)':'Fat_Poly.',
    'FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)':'DHA',
    'Salt (g/100g)':'Salt',
    'Iodine (µg/100g)':'Iodine',
    'Vitamin K1 (µg/100g)':'Vitamin_K1',
    'Vitamin K2 (µg/100g)':'Vitamin_K2'
    },inplace=True)
food1.shape
# Out:
# (2807, 46)

# %%
food1=food1.assign(**{'Sucrose':0,'Glucose':0, 'Fructose':0,'Lactose':0,'Maletose':0,'Caffeine':0,'Theobromine':0,'Galactose':0,'Fluoride':0,'Vitamin A':0, 'Alpha_Carotene':0, 'Vitamin_D2':0,'Vitamin_D3':0,'Beta_Cryptoxanthin':0,'Lycopene':0, 'Lutein&Zeaxathin':0})    
food1.shape
# Out:
# (2807, 62)

# %%
food1.columns
# Out:
# Index(['Group', 'Name', 'Calories', 'Water', 'Protein', 'Carbohydrates', 'Fat',
#        'Sugar', 'Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol',
#        'Organic_Acids', 'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA',
#        'Cholesterol', 'Salt', 'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine',
#        'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Sodium', 'Zinc', 'Retinol', 'Beta_Carotene', 'Vitamin_D', 'Vitamin_E',
#        'Vitamin_K1', 'Vitamin_K2', 'Vitamin_C', 'Vitamin_B1', 'Vitamin_B2',
#        'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6', 'Vitamin_B9', 'Vitamin_B12',
#        'Sucrose', 'Glucose', 'Fructose', 'Lactose', 'Maletose', 'Caffeine',
#        'Theobromine', 'Galactose', 'Fluoride', 'Vitamin A', 'Alpha_Carotene',
#        'Vitamin_D2', 'Vitamin_D3', 'Beta_Cryptoxanthin', 'Lycopene',
#        'Lutein&Zeaxathin'],
#       dtype='object')

# %%
food1=food1[['Group', 'Name', 'Calories', 'Water', 'Protein', 'Carbohydrates', 'Fat',
       'Sugar', 'Sucrose', 'Glucose', 'Fructose', 'Lactose', 'Maletose','Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol',
       'Organic_Acids', 'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA',
       'Cholesterol', 'Salt', 'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine',
       'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
       'Sodium', 'Zinc', 'Retinol','Alpha_Carotene', 'Beta_Carotene','Caffeine','Theobromine', 'Galactose', 'Fluoride','Beta_Cryptoxanthin', 'Lycopene',
       'Lutein&Zeaxathin','Vitamin A','Vitamin_B1', 'Vitamin_B2',
       'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6', 'Vitamin_B9', 'Vitamin_B12', 'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3','Vitamin_D', 'Vitamin_E',
       'Vitamin_K1', 'Vitamin_K2']]

# %%
food2=food2[['Group', 'Name', 'Calories', 'Water', 'Protein', 'Carbohydrates', 'Fat',
       'Sugar', 'Sucrose', 'Glucose', 'Fructose', 'Lactose', 'Maletose','Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol',
       'Organic_Acids', 'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA',
       'Cholesterol', 'Salt', 'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine',
       'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
       'Sodium', 'Zinc', 'Retinol','Alpha_Carotene', 'Beta_Carotene','Caffeine','Theobromine', 'Galactose', 'Fluoride','Beta_Cryptoxanthin', 'Lycopene',
       'Lutein&Zeaxathin','Vitamin A','Vitamin_B1', 'Vitamin_B2',
       'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6', 'Vitamin_B9', 'Vitamin_B12', 'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3','Vitamin_D', 'Vitamin_E',
       'Vitamin_K1', 'Vitamin_K2']]

# %%
col_food1=food1.columns 
col_food2=food2.columns
print(col_food1==col_food2)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]

# %%
food1.shape
# Out:
# (2807, 62)

# %%
food2.shape
# Out:
# (6347, 62)

# %%
frames = [food1, food2]
food_properties= pd.concat(frames)

# %%
food_properties=food_properties.reset_index()

# %%
food_properties.columns
# Out:
# Index(['index', 'Group', 'Name', 'Calories', 'Water', 'Protein',
#        'Carbohydrates', 'Fat', 'Sugar', 'Sucrose', 'Glucose', 'Fructose',
#        'Lactose', 'Maletose', 'Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol',
#        'Organic_Acids', 'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA',
#        'Cholesterol', 'Salt', 'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine',
#        'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Sodium', 'Zinc', 'Retinol', 'Alpha_Carotene', 'Beta_Carotene',
#        'Caffeine', 'Theobromine', 'Galactose', 'Fluoride',
#        'Beta_Cryptoxanthin', 'Lycopene', 'Lutein&Zeaxathin', 'Vitamin A',
#        'Vitamin_B1', 'Vitamin_B2', 'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6',
#        'Vitamin_B9', 'Vitamin_B12', 'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3',
#        'Vitamin_D', 'Vitamin_E', 'Vitamin_K1', 'Vitamin_K2'],
#       dtype='object')

# %%
food_properties.drop(columns='index', inplace=True)

# %%
print(food_properties.dtypes)
# Out:
# Group                  object
# Name                   object
# Calories               object
# Water                  object
# Protein                object
# Carbohydrates          object
# Fat                    object
# Sugar                  object
# Sucrose               float64
# Glucose               float64
# Fructose              float64
# Lactose               float64
# Maletose              float64
# Starch                 object
# Fiber                  object
# Polyols                object
# Ash                    object
# Alcohol                object
# Organic_Acids          object
# Saturated_Fat          object
# Fat_Mono.              object
# Fat_Poly.              object
# DHA                    object
# Cholesterol            object
# Salt                   object
# Calcium                object
# Choline                object
# Cupper                 object
# Iron                   object
# Iodine                 object
#                        ...
# ...

# %%
food_properties['Name'].value_counts()
# Out:
# Almond cake                                                                                       2
# Wild rice, raw                                                                                    2
# Golden redfish, raw                                                                               2
# Candies, marshmallows                                                                             2
# Watercress, raw                                                                                   2
# Rosemary, fresh                                                                                   2
# Wafer cookie                                                                                      2
# Thyme, fresh                                                                                      2
# Basil, fresh                                                                                      2
# ...

# %%
food_properties.shape
# Out:
# (9154, 62)

# %%
import textdistance

def generateScores(string, toFind):
    score=textdistance.cosine(string, toFind)
    return score

palabras = 'Apples raw'
display(generateScores(palabras,"raw Apples"))
# Out:
# 1.0

# %%
counter=0
quitar=[]
for i in food_properties['Name']:
    #p=food_properties['Name'][i]
    if i not in quitar:
        for e in food_properties['Name']:
            if e not in quitar:
                comparing=generateScores(i,e)
                if 1 >comparing > 0.90:
                    quitar.append(e)
                    counter+=1
print(counter)
print(quitar)
# Out:
# 2891
# ...

# %%
len(set(quitar))
# Out:
# 2891

# %%
food_properties= food_properties[~food_properties['Name'].isin(quitar)]
food_properties
# Out:
#                                   Group  \
# 0                          mixed salads
# 1                          mixed salads
# 2                          mixed salads
# 3                          mixed salads
# 4                          mixed salads
# 5                          mixed salads
# 6                          mixed salads
# 7                          mixed salads
# 8                          mixed salads
# 9                          mixed salads
# 10                         mixed salads
# 11                         mixed salads
# 12                         mixed salads
# 13                         mixed salads
# 14                                 soup
# 15                                 soup
# 17                                 soup
# 18                                 soup
# 19                                 soup
# 20                                 soup
# 21                                 soup
# 23                                 soup
# ...

# %%
#counter=0
#for i in food_properties['Name']:
#    for e in food_properties['Name']:
#        comparing=generateScores(i,e)
#        if 1 >comparing > 0.75:
#            print([i,e,comparing])
#            counter+=1
#print(counter)

# %%
#resultado=dict()
#parecidos=[]
#for a in food_properties['Name'][:50]:
#    resultado[a]=[]
#    for b in food_properties['Name'][:50]:
#        aux=[]
#        comparing=generateScores(i,e)
#        if 1 > comparing > 0.75 and b not in parecidos:
#            aux.append(b)
#            parecidos.append(b)
#resultado[a]=aux
#print (resultado[a])

# %%
food_properties = food_properties.drop_duplicates(subset=['Name'], keep='first')

# %%
food_properties=food_properties.reset_index()

# %%
food_properties.drop(columns='index', inplace=True)

# %%
food_properties.isna().sum()
# Out:
# Group                   11
# Name                     0
# Calories                 1
# Water                    3
# Protein                  0
# Carbohydrates            1
# Fat                      1
# Sugar                  885
# Sucrose               3058
# Glucose               3051
# Fructose              3047
# Lactose               3077
# Maletose              3071
# Starch                3350
# Fiber                  253
# Polyols                 10
# Ash                     30
# Alcohol               1152
# Organic_Acids            7
# Saturated_Fat          170
# Fat_Mono.                6
# Fat_Poly.                9
# DHA                     33
# Cholesterol            162
# Salt                     5
# Calcium                 60
# Choline               1622
# Cupper                 403
# Iron                    53
# Iodine                  17
#                       ...
# Phosphorus             247
# Potassium              156
# Selenium               573
# ...

# %%
food_properties
# Out:
#                                   Group  \
# 0                          mixed salads
# 1                          mixed salads
# 2                          mixed salads
# 3                          mixed salads
# 4                          mixed salads
# 5                          mixed salads
# 6                          mixed salads
# 7                          mixed salads
# 8                          mixed salads
# 9                          mixed salads
# 10                         mixed salads
# 11                         mixed salads
# 12                         mixed salads
# 13                         mixed salads
# 14                                 soup
# 15                                 soup
# 16                                 soup
# 17                                 soup
# 18                                 soup
# 19                                 soup
# 20                                 soup
# 21                                 soup
# ...

# %%
food_properties=food_properties[['Group', 'Name', 'Calories', 'Water', 'Protein',
       'Carbohydrates', 'Fat', 'Sugar', 'Sucrose', 'Glucose', 'Fructose',
       'Lactose', 'Maletose', 'Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol',
       'Organic_Acids', 'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA',
       'Cholesterol', 'Salt', 'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine',
       'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
       'Sodium', 'Zinc', 'Retinol', 'Alpha_Carotene', 'Beta_Carotene',
       'Caffeine', 'Theobromine', 'Galactose', 'Fluoride',
       'Beta_Cryptoxanthin', 'Lycopene', 'Lutein&Zeaxathin', 'Vitamin A',
       'Vitamin_B1', 'Vitamin_B2', 'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6',
       'Vitamin_B9', 'Vitamin_B12', 'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3',
       'Vitamin_D', 'Vitamin_E', 'Vitamin_K1', 'Vitamin_K2']].fillna('0')

# %%
food_properties.isna().sum()
# Out:
# Group                 0
# Name                  0
# Calories              0
# Water                 0
# Protein               0
# Carbohydrates         0
# Fat                   0
# Sugar                 0
# Sucrose               0
# Glucose               0
# Fructose              0
# Lactose               0
# Maletose              0
# Starch                0
# Fiber                 0
# Polyols               0
# Ash                   0
# Alcohol               0
# Organic_Acids         0
# Saturated_Fat         0
# Fat_Mono.             0
# Fat_Poly.             0
# DHA                   0
# Cholesterol           0
# Salt                  0
# Calcium               0
# Choline               0
# Cupper                0
# Iron                  0
# Iodine                0
#                      ..
# Phosphorus            0
# Potassium             0
# Selenium              0
# Sodium                0
# Zinc                  0
# Retinol               0
# Alpha_Carotene        0
# ...

# %%
food_properties[food_properties['Name'].str.contains("Apple ")]
# Out:
#                         Group  \
# 615                    fruits
# 821       breads and pastries
# 953                     cakes
# 955                     cakes
# 957                     cakes
# 2000  non-alcoholic beverages
# 3141  Fruits and Fruit Juices
# 3142  Fruits and Fruit Juices
# 4213                Beverages
# 4252                Beverages
#
#                                                    Name Calories  Water  \
# 615                                       Apple compote      102   72,9
# 821                                      Apple turnover      338   36,2
# 953   Apple pie with custard (flour, eggs, cream, su...      313   38,6
# 955                                          Apple tart      227   50,4
# 957                                       Apple crumble      242   48,7
# 2000                            Apple juice, pure juice     42,7   88,4
# 3141  Apple juice, canned or bottled, unsweetened, w...       46  88.24
# ...

# %%
food_properties.columns
# Out:
# Index(['Group', 'Name', 'Calories', 'Water', 'Protein', 'Carbohydrates', 'Fat',
#        'Sugar', 'Sucrose', 'Glucose', 'Fructose', 'Lactose', 'Maletose',
#        'Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol', 'Organic_Acids',
#        'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA', 'Cholesterol', 'Salt',
#        'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine', 'Magnesium',
#        'Manganese', 'Phosphorus', 'Potassium', 'Selenium', 'Sodium', 'Zinc',
#        'Retinol', 'Alpha_Carotene', 'Beta_Carotene', 'Caffeine', 'Theobromine',
#        'Galactose', 'Fluoride', 'Beta_Cryptoxanthin', 'Lycopene',
#        'Lutein&Zeaxathin', 'Vitamin A', 'Vitamin_B1', 'Vitamin_B2',
#        'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6', 'Vitamin_B9', 'Vitamin_B12',
#        'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3', 'Vitamin_D', 'Vitamin_E',
#        'Vitamin_K1', 'Vitamin_K2'],
#       dtype='object')

# %%
food_properties=food_properties.astype(str)

# %%
def deleting_simbols(x):
    if '<' in x:
        x=x.replace('<', '')
        return x
    else:return x
    
def normalizing_floats(x):  
    if ',' in x:
        x= deleting_simbols (x.replace(',', '.'))
        return x
    else:
        x=deleting_simbols(x)
        return x

food_properties=food_properties.applymap(normalizing_floats)

# %%
food_properties.head()
# Out:
#           Group                                               Name Calories  \
# 0  mixed salads             Celeriac in remoulade sauce. prepacked        -
# 1  mixed salads  Prepared mixed tuna and vegetable salad. canne...        -
# 2  mixed salads     Prepared mixed meat/fish canned. drained salad        -
# 3  mixed salads                    Greek-style marinated mushrooms        -
# 4  mixed salads                 Prepared potatoes salad. home-made        -
#
#   Water Protein Carbohydrates   Fat Sugar Sucrose Glucose  ... Vitamin_B6  \
# 0  78.5    1.12          4.19  12.8  2.38     0.0     0.0  ...       0.19
# 1  76.5    9.15          7.74   4.7  3.08     0.0     0.0  ...       0.29
# 2  76.7    8.06           6.4   5.3   1.9     0.0     0.0  ...       0.12
# 3  84.6    2.08          3.95  3.55  2.38     0.0     0.0  ...       0.11
# 4    76    2.68           9.9   8.2     -     0.0     0.0  ...       0.14
#
# ...

# %%
food_properties=food_properties.replace({'-': '0', 'traces':'0.01'})
food_properties.head()
# Out:
#           Group                                               Name Calories  \
# 0  mixed salads             Celeriac in remoulade sauce. prepacked        0
# 1  mixed salads  Prepared mixed tuna and vegetable salad. canne...        0
# 2  mixed salads     Prepared mixed meat/fish canned. drained salad        0
# 3  mixed salads                    Greek-style marinated mushrooms        0
# 4  mixed salads                 Prepared potatoes salad. home-made        0
#
#   Water Protein Carbohydrates   Fat Sugar Sucrose Glucose  ... Vitamin_B6  \
# 0  78.5    1.12          4.19  12.8  2.38     0.0     0.0  ...       0.19
# 1  76.5    9.15          7.74   4.7  3.08     0.0     0.0  ...       0.29
# 2  76.7    8.06           6.4   5.3   1.9     0.0     0.0  ...       0.12
# 3  84.6    2.08          3.95  3.55  2.38     0.0     0.0  ...       0.11
# 4    76    2.68           9.9   8.2     0     0.0     0.0  ...       0.14
#
# ...

# %%
all_number_columns=['Calories', 'Water', 'Protein', 'Carbohydrates', 'Fat',
       'Sugar', 'Sucrose', 'Glucose', 'Fructose', 'Lactose', 'Maletose',
       'Starch', 'Fiber', 'Polyols', 'Ash', 'Alcohol', 'Organic_Acids',
       'Saturated_Fat', 'Fat_Mono.', 'Fat_Poly.', 'DHA', 'Cholesterol', 'Salt',
       'Calcium', 'Choline', 'Cupper', 'Iron', 'Iodine', 'Magnesium',
       'Manganese', 'Phosphorus', 'Potassium', 'Selenium', 'Sodium', 'Zinc',
       'Retinol', 'Alpha_Carotene', 'Beta_Carotene', 'Caffeine', 'Theobromine',
       'Galactose', 'Fluoride', 'Beta_Cryptoxanthin', 'Lycopene',
       'Lutein&Zeaxathin', 'Vitamin A', 'Vitamin_B1', 'Vitamin_B2',
       'Vitamin_B3', 'Vitamin_B5', 'Vitamin_B6', 'Vitamin_B9', 'Vitamin_B12',
       'Vitamin_C', 'Vitamin_D2', 'Vitamin_D3', 'Vitamin_D', 'Vitamin_E',
       'Vitamin_K1', 'Vitamin_K2']


food_properties[food_properties.isin(['< 1'])].stack()
# Out:
# Series([], dtype: object)

# %%
food_properties[all_number_columns]=food_properties[all_number_columns].astype(float)
food_properties.dtypes
# Out:
# Group                  object
# Name                   object
# Calories              float64
# Water                 float64
# Protein               float64
# Carbohydrates         float64
# Fat                   float64
# Sugar                 float64
# Sucrose               float64
# Glucose               float64
# Fructose              float64
# Lactose               float64
# Maletose              float64
# Starch                float64
# Fiber                 float64
# Polyols               float64
# Ash                   float64
# Alcohol               float64
# Organic_Acids         float64
# Saturated_Fat         float64
# Fat_Mono.             float64
# Fat_Poly.             float64
# DHA                   float64
# Cholesterol           float64
# Salt                  float64
# Calcium               float64
# Choline               float64
# Cupper                float64
# Iron                  float64
# Iodine                float64
#                        ...
# ...

# %%
def deleting_raw(x):
    if 'raw ' in x:
        x=x.replace('raw ', '')
        return x
    else:return x

# %%
food_properties['Name']=food_properties['Name'].apply(deleting_raw)

# %%
food_properties[food_properties['Name'].str.contains("raw")]
# Out:
#                                   Group  \
# 123                              dishes
# 124                              dishes
# 125                              dishes
# 158                              dishes
# 272                          vegetables
# 273                          vegetables
# 274                          vegetables
# 275                          vegetables
# 276                          vegetables
# 277                          vegetables
# 278                          vegetables
# 279                          vegetables
# 280                          vegetables
# 281                          vegetables
# 282                          vegetables
# 283                          vegetables
# 284                          vegetables
# 285                          vegetables
# 286                          vegetables
# 287                          vegetables
# 288                          vegetables
# 289                          vegetables
# ...

# %%
food_properties.to_csv('food_properties_normalized.csv')

# %% [markdown]
# def generateScores(lst, metric, toFind):
#     scores = enumerate(map(lambda x :metric(toFind,x), lst))
#     scores = sorted(scores, key=lambda x:x[1])
#     index, score = scores[0]
#     return {
#         "most_similar":lst[index],
#         "score_similar":score,
#         "sorted_list": list(map(lambda x: (lst[x[0]], x[1]), scores))[:10]
#     }
#
# metric1 = textdistance.levenshtein.distance
# metric2 = textdistance.hamming.normalized_distance
# metric3 = textdistance.mlipns.normalized_distance
# metric4 = textdistance.damerau_levenshtein.distance
# metric5 = textdistance.jaro_winkler.distance
#
# palabras = food_properties['Name']
# display(generateScores(palabras,metric5,"Apple, compote"))
